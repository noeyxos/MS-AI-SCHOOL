# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# load titanic dataset
titanic = sns.load_dataset('titanic')

print(titanic)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class
# 0           0       3    male  22.0      1      0   7.2500        S   Third  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# create a pointplot with Sex, pclass, and survived variables
sns.pointplot(x='sex', y='survived', hue='pclass', data=titanic)

# add legend
plt.legend(title='Pclass', loc='best')

# set plot title
plt.title('Survived Rate by Sex and Pclass')
# Out:
# Text(0.5, 1.0, 'Survived Rate by Sex and Pclass')

# %%
pip install statsmodels
# Out:
# ...
#
# ...
#      ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#      -- ------------------------------------- 0.6/9.4 MB 17.8 MB/s eta 0:00:01
#      ----------- ---------------------------- 2.6/9.4 MB 28.2 MB/s eta 0:00:01
#      ---------------- ----------------------- 3.8/9.4 MB 27.2 MB/s eta 0:00:01
#      ----------------------- ---------------- 5.6/9.4 MB 29.7 MB/s eta 0:00:01
#      ---------------------------------- ----- 8.0/9.4 MB 34.1 MB/s eta 0:00:01
#      ---------------------------------------  9.4/9.4 MB 37.4 MB/s eta 0:00:01
#      ---------------------------------------- 9.4/9.4 MB 31.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/233.8 kB ? eta -:--:--
#      ---------------------------------------- 233.8/233.8 kB ? eta 0:00:00
# ...

# %%
import pandas as pd
import seaborn as sns
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
# 데이터 불러오기 
titanic_df = pd.read_csv('./data/Titanic_data.csv')

# print(titanic_df)

# 이원 분산 분석 모델 생성
model = ols('Survived ~ C(Sex) + C(Pclass) + C(Sex):C(Pclass)',titanic_df).fit()

#분산 분석 실행
anova_results = anova_lm(model,type=2)

#시각화
sns.catplot(x='Sex', y= 'Survived', hue='Pclass', data=titanic_df, kind='bar')

# %%
#ols 함수: Ordinary Least Squares(OLS) 회귀 모델을 생성하는 함수입니다. 
#주어진 종속 변수와 독립 변수를 기반으로 선형 회귀 모델을 적합시킵니다.
#일반적으로 통계적 가설 검정, 회귀 분석, 분산 분석 등에 사용됩니다.
#ols 함수는 선형 모델을 구축하기 위해 회귀식을 지정하는데 사용됩니다. 
#주어진 데이터와 회귀식을 기반으로 최소 제곱법을 사용하여 모델을 적합시킵니다.

#anova_lm 함수: 분산 분석(ANOVA, Analysis of Variance)을 수행하는 함수입니다. 
# 주어진 모델에서 변수 간의 통계적 차이를 분석합니다. 
# 주로 카테고리 변수(범주형 변수) 간의 평균 차이를 검정하는 데 사용됩니다. 
# anova_lm 함수는 주어진 모델에 대한 분산 분석 테이블을 생성합니다. 
# 이 테이블은 각 변수의 효과 크기, 자유도, F-통계량, p-값 등을 제공하여 
#변수 간의 유의미한 차이를 확인할 수 있습니다.
